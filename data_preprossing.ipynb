# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Jeevan kumar\Downloads\data.csv")
df.sample(5)
# Out:
#                      date     price  bedrooms  bathrooms  sqft_living  \
# 3610  2014-06-28 00:00:00  234000.0       3.0        1.0         1040
# 873   2014-05-19 00:00:00  690000.0       3.0        2.0         1610
# 3066  2014-06-23 00:00:00  291500.0       3.0        1.0          880
# 3466  2014-06-26 00:00:00  354000.0       4.0        2.5         2580
# 287   2014-05-07 00:00:00  239900.0       3.0        2.0         1410
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 3610      8128     1.0           0     0          3        1040
# 873       5100     1.5           0     0          5        1610
# 3066      9238     1.5           0     0          5         880
# 3466      5476     2.0           0     0          3        2580
# 287       7566     1.0           0     0          3        1410
#
#       sqft_basement  yr_built  yr_renovated               street       city  \
# 3610              0      1983          2009  26720 NE Stewart St     Duvall
# ...

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df.waterfront.value_counts()
# Out:
# waterfront
# 0    4567
# 1      33
# Name: count, dtype: int64

# %%
df.view.value_counts()
# Out:
# view
# 0    4140
# 2     205
# 3     116
# 4      70
# 1      69
# Name: count, dtype: int64

# %%
df.yr_renovated.value_counts()
# Out:
# yr_renovated
# 0       2735
# 2000     170
# 2003     151
# 2009     109
# 2001     109
# 2005      95
# 2004      77
# 2014      72
# 2006      68
# 2013      61
# 1994      57
# 1923      57
# 1989      55
# 2011      54
# 2008      45
# 2012      45
# 1988      43
# 1999      41
# 1983      41
# 2002      41
# 1998      40
# 1993      39
# 1912      33
# 1992      32
# 1979      32
# 2010      30
# 1985      29
# 1997      28
# 1982      22
# 1996      22
# 1972      17
# 1990      16
# 1956      15
# 1963      12
# 1969      11
# 1984      10
# 1970       9
# 1968       9
# 1954       8
# 1945       7
# 2007       7
# 1974       6
# 1934       6
# 1958       5
# 1986       5
# 1971       5
# 1978       3
# 1995       2
# 1955       2
# 1980       2
# 1981       1
# 1953       1
# 1966       1
# 1987       1
# 1960       1
# 1948       1
# 1991       1
# 1913       1
# 1977       1
# 1975       1
# Name: count, dtype: int64

# %%
df.country.value_counts()
# Out:
# country
# USA    4600
# Name: count, dtype: int64

# %%
df.city.value_counts()
# Out:
# city
# Seattle                1561
# Renton                  291
# Bellevue                281
# Redmond                 235
# Kirkland                187
# Issaquah                186
# Kent                    184
# Auburn                  175
# Sammamish               171
# Federal Way             145
# Shoreline               123
# Woodinville             114
# Maple Valley             95
# Mercer Island            82
# Burien                   72
# Snoqualmie               69
# Kenmore                  65
# Des Moines               58
# North Bend               50
# Duvall                   42
# Covington                42
# Lake Forest Park         34
# Bothell                  33
# Newcastle                33
# Tukwila                  29
# Vashon                   29
# SeaTac                   28
# Enumclaw                 27
# Carnation                22
# Normandy Park            17
# Fall City                11
# Medina                   11
# Clyde Hill                9
# ...

# %%
df.shape
# Out:
# (4600, 18)

# %%
df.price.describe()
# Out:
# count    4.600000e+03
# mean     5.519630e+05
# std      5.638347e+05
# min      0.000000e+00
# 25%      3.228750e+05
# 50%      4.609435e+05
# 75%      6.549625e+05
# max      2.659000e+07
# Name: price, dtype: float64

# %%
df = df.drop(index=df[df['price'] == 0].index)

# %%
df.shape
# Out:
# (4551, 18)

# %%
df.price.describe()
# Out:
# count    4.551000e+03
# mean     5.579059e+05
# std      5.639299e+05
# min      7.800000e+03
# 25%      3.262643e+05
# 50%      4.650000e+05
# 75%      6.575000e+05
# max      2.659000e+07
# Name: price, dtype: float64

# %%
df.bathrooms=df['bathrooms'].astype(int)

# %%
df.floors=df['floors'].astype(int)

# %%
df.sample(5)
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 3804  2014-07-01 00:00:00  640000.000000       2.0          2         1540
# 4186  2014-07-09 00:00:00  610000.000000       3.0          2         2630
# 3464  2014-06-26 00:00:00  450000.000000       2.0          1          840
# 1741  2014-06-03 00:00:00  850000.000000       3.0          1         1370
# 4488  2014-06-12 00:00:00  210614.285714       3.0          2         2210
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 3804       965       3           0     0          3        1540
# 4186      5827       2           0     0          3        2630
# 3464      3340       1           0     0          3         700
# 1741      3850       1           0     0          5         770
# 4488     10119       1           0     0          4        1450
#
#       sqft_basement  yr_built  yr_renovated               street     city  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['city_e'] = le.fit_transform(df['city'])

# %%
df['has_renovated'] = (df['yr_renovated'] != 0).astype(int)

# %%
df.sample(5)
# Out:
#                      date     price  bedrooms  bathrooms  sqft_living  \
# 699   2014-05-14 00:00:00  450000.0       3.0          2         2910
# 722   2014-05-15 00:00:00  455000.0       3.0          2         1870
# 3638  2014-06-30 00:00:00  491950.0       3.0          2         2090
# 3555  2014-06-27 00:00:00  725000.0       3.0          2         3580
# 3727  2014-07-01 00:00:00  300000.0       3.0          2         1660
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 699      17172     2.0           0     0          3        2910
# 722       7344     1.0           0     0          3        1470
# 3638     10733     1.0           0     0          3        1440
# 3555     54450     1.5           0     0          3        3580
# 3727      5128     2.0           0     0          3        1660
#
#       sqft_basement  yr_built  yr_renovated             street          city  \
# 699               0      1989             0    36023 3rd Ave S   Federal Way
# ...

# %%
df.price.describe()
# Out:
# count    4.551000e+03
# mean     5.579059e+05
# std      5.639299e+05
# min      7.800000e+03
# 25%      3.262643e+05
# 50%      4.650000e+05
# 75%      6.575000e+05
# max      2.659000e+07
# Name: price, dtype: float64

# %%
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

df = df[(df['price'] >= Q1 - 1.5*IQR) & (df['price'] <= Q3 + 1.5*IQR)]

# %%
df.price.describe()
# Out:
# count    4.311000e+03
# mean     4.874569e+05
# std      2.156596e+05
# min      7.800000e+03
# 25%      3.200000e+05
# 50%      4.500000e+05
# 75%      6.150000e+05
# max      1.150000e+06
# Name: price, dtype: float64

# %%
per_99=df.price.quantile(0.99)
per_99
# Out:
# np.float64(2016000.0)

# %%
df.price.quantile(0.1)
# Out:
# np.float64(245000.0)

# %%
df['z_score'] = (df['price'] - df['price'].mean()) / df['price'].std()

# %%
df[df['z_score']> df['z_score'].quantile(0.999)]
# Out:
#                      date       price  bedrooms  bathrooms  sqft_living  \
# 2286  2014-06-11 00:00:00   7062500.0       5.0          4        10040
# 2654  2014-06-17 00:00:00   4668000.0       5.0          6         9640
# 2761  2014-06-18 00:00:00   4489000.0       4.0          3         6430
# 4346  2014-06-23 00:00:00  12899000.0       3.0          2         2190
# 4350  2014-07-03 00:00:00  26590000.0       3.0          2         1180
#
#       sqft_lot  floors  waterfront  view  condition  ...  sqft_basement  \
# 2286     37325       2           1     2          3  ...           2360
# 2654     13068       1           1     4          3  ...           4820
# 2761     27517       2           0     0          3  ...              0
# 4346     11394       1           0     0          3  ...            640
# 4350      7793       1           0     0          4  ...              0
#
#       yr_built  yr_renovated                 street           city  statezip  \
# ...

# %%
df=df[df['z_score']< df['z_score'].quantile(0.999)]

# %%
df.city_e.value_counts()
# Out:
# city_e
# 35    1560
# 32     291
# 3      279
# 31     235
# 19     187
# 16     186
# 18     183
# 1      175
# 33     171
# 14     145
# 36     123
# 42     114
# 21      95
# 23      81
# 6       72
# 38      69
# 17      65
# 10      58
# 27      50
# 11      42
# 9       42
# 20      34
# 5       33
# 25      33
# 40      29
# 41      29
# 34      28
# 12      27
# 7       22
# 26      17
# 13      11
# 22      11
# 8        9
# 4        8
# 30       7
# 28       6
# 0        5
# 43       4
# 37       3
# 29       2
# 24       2
# 15       1
# 39       1
# 2        1
# Name: count, dtype: int64

# %%
df.yr_renovated.value_counts()
# Out:
# yr_renovated
# 0       2700
# 2000     168
# 2003     149
# 2009     106
# 2001     104
# 2005      94
# 2004      77
# 2014      72
# 2006      66
# 2013      61
# 1994      57
# 1989      55
# 1923      55
# 2011      54
# 2008      45
# 2012      45
# 1988      43
# 1983      40
# 2002      40
# 1999      39
# 1998      39
# 1993      39
# 1912      33
# 1992      32
# 1979      32
# 2010      30
# 1985      29
# 1997      28
# 1982      22
# 1996      21
# 1972      17
# 1990      16
# 1956      15
# 1963      12
# 1969      11
# 1970       9
# 1984       9
# 1968       9
# 1954       8
# 1945       7
# 2007       7
# 1974       6
# 1934       6
# 1958       5
# 1986       5
# 1971       5
# 1978       3
# 1995       2
# 1955       2
# 1980       2
# 1981       1
# 1953       1
# 1966       1
# 1987       1
# 1960       1
# 1948       1
# 1991       1
# 1913       1
# 1977       1
# Name: count, dtype: int64

# %%
df.floors.value_counts()
# Out:
# floors
# 1    2587
# 2    1830
# 3     129
# Name: count, dtype: int64

# %%
df.bathrooms.value_counts()
# Out:
# bathrooms
# 2    2290
# 1    1654
# 3     490
# 4      72
# 0      19
# 5      13
# 8       1
# 6       1
# Name: count, dtype: int64

# %%
df.price.describe()
# Out:
# count    4.546000e+03
# mean     5.462651e+05
# std      3.452434e+05
# min      7.800000e+03
# 25%      3.260250e+05
# 50%      4.650000e+05
# 75%      6.570000e+05
# max      3.800000e+06
# Name: price, dtype: float64

# %%
st=df.price.std()
st
# Out:
# np.float64(330570.7587935672)

# %%
mean=df.price.mean()
mean
# Out:
# np.float64(542648.2922856354)

# %%
ls=mean - 4*st
hs=mean + 4*st
print(ls,hs)
# Out:
# -779634.7428886334 1864931.3274599041

# %%
df[(df['price'] < ls) | (df['price'] > hs)]
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 1     2014-05-02 00:00:00  2.384000e+06       5.0          2         3650
# 122   2014-05-05 00:00:00  2.280000e+06       7.0          8        13540
# 252   2014-05-07 00:00:00  3.200000e+06       7.0          4         6210
# 404   2014-05-09 00:00:00  2.400000e+06       3.0          2         3000
# 462   2014-05-09 00:00:00  2.238888e+06       5.0          6         7270
# 581   2014-05-13 00:00:00  2.555000e+06       4.0          2         5300
# 745   2014-05-15 00:00:00  2.100000e+06       4.0          1         3550
# 839   2014-05-16 00:00:00  2.000000e+06       5.0          4         6490
# 1132  2014-05-21 00:00:00  2.700000e+06       5.0          4         5305
# 1209  2014-05-22 00:00:00  2.150000e+06       4.0          5         5060
# 1301  2014-05-24 00:00:00  2.000000e+06       5.0          4         4580
# 1500  2014-05-28 00:00:00  1.970000e+06       8.0          3         4440
# ...

# %%
df[df['z_score'] > 4]
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 252   2014-05-07 00:00:00  3200000.0       7.0          4         6210
# 1567  2014-05-29 00:00:00  3100000.0       6.0          4         6980
# 1637  2014-05-30 00:00:00  3710000.0       4.0          3         5550
# 2328  2014-06-11 00:00:00  2888000.0       5.0          6         8670
# 2772  2014-06-18 00:00:00  3000000.0       4.0          4         4850
# 3729  2014-07-01 00:00:00  3800000.0       5.0          5         7050
#
#       sqft_lot  floors  waterfront  view  condition  ...  sqft_basement  \
# 252       8856     2.5           0     2          5  ...           1450
# 1567     15682     3.0           0     4          4  ...           1650
# 1637     28078     2.0           0     2          4  ...           2200
# 2328     64033     2.0           0     4          3  ...           2550
# 2772     12445     2.0           1     4          5  ...           1000
# ...

# %%
df=df[df['z_score'] < 4]

# %%
df.price.hist(bins=50, edgecolor='black')
# Out:
# <Axes: >

# %%
df['price'] = np.log1p(df['price'])

# %%
df.price.hist(bins=50, edgecolor='black')
# Out:
# <Axes: >

# %%
df[(df['z_score']< -3)]
# Out:
# Empty DataFrame
# Columns: [date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, sqft_above, sqft_basement, yr_built, yr_renovated, street, city, statezip, country, city_e, has_renovated, z_score]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.price.describe()
# Out:
# count    4311.000000
# mean       12.996122
# std         0.462297
# min         8.962007
# 25%        12.676079
# 50%        13.017005
# 75%        13.329379
# max        13.955273
# Name: price, dtype: float64

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country', 'city_e', 'has_renovated', 'z_score'],
#       dtype='str')

# %%
df.sample(5)
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 1080  2014-05-21 00:00:00  13.818507       4.0          2         2290
# 2894  2014-06-19 00:00:00  13.122365       3.0          2         2840
# 380   2014-05-08 00:00:00  13.635188       4.0          2         1910
# 9     2014-05-02 00:00:00  13.369225       4.0          2         1520
# 2880  2014-06-19 00:00:00  12.772667       3.0          2         1430
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 1080      6120       2           0     0          4        2170
# 2894     48716       1           0     3          3        1870
# 380       6960       1           0     0          5        1910
# 9         6200       1           0     0          3        1520
# 2880      6000       1           0     0          5        1430
#
#       sqft_basement  yr_built  yr_renovated             street       city  \
# 1080            120      1926          1993     124 NE 63rd St    Seattle
# ...

# %%
X = df[['bedrooms','bathrooms','floors','waterfront','yr_built','yr_renovated','city_e']]  # Features
y = df['price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
model.predict([[3, 2, 1, 0, 2000, 0, 43]])
# Out:
# C:\Users\Jeevan kumar\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([13.42585668])

# %%
model.predict([[3, 2, 3, 0, 1995, 2010, 25]])
# Out:
# C:\Users\Jeevan kumar\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([13.29847132])

# %%
model.score(X_test, y_test)
# Out:
# 0.7642493068250369

# %%
from sklearn import linear_model
lm = linear_model.LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lm.predict([[2, 3, 1, 0, 2012, 0, 35]])
# Out:
# C:\Users\Jeevan kumar\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([13.04916304])

# %%
lm.score(X_test, y_test)
# Out:
# 0.24932494793825044

# %%
import pickle

# %%
with open('model.pkl', 'wb') as f:
    pickle.dump(model, f)
